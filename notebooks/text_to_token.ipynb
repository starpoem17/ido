# %%
from tokenizers import Tokenizer
from pathlib import Path
import torch

# %%
train_text = Path('../data/tiny_shakespeare_train.txt').read_text(encoding='utf-8')

# %%
len(train_text)
# Out:
# 1003855

# %%
tokenizer = Tokenizer.from_file('../data/shakespeare_bpe.json')

# %%
encoding = tokenizer.encode(train_text)

# %%
ids = encoding.ids

# %%
print(ids)
# Out:
# [5720, 1010, 13, 68, 2156, 145, 2561, 616, 2116, 9, 488, 131, 430, 11, 68, 68, 1045, 13, 68, 2352, 9, 430, 11, 68, 68, 485, 1010, 13, 68, 379, 232, 209, 4006, 1312, 101, 778, 341, 101, 7732, 15, 68, 68, 1045, 13, 68, 11712, 11, 4006, 11, 68, 68, 485, 1010, 13, 68, 485, 9, 102, 318, 3806, 1231, 138, 3567, 1755, 101, 81, 1006, 11, 68, 68, 1045, 13, 68, 481, 318, 480, 9, 145, 318, 480, 11, 68, 68, 485, 1010, 13, 68, 758, 344, 1128, 174, 9, 110, 145, 269, 169, 2958, 273, 226, 643, 5482, 11, 68, 576, 480, 72, 11630, 15, 68, 68, 1045, 13, 68, 502, 298, 6662, 182, 480, 14, 351, 152, 118, 654, 13, 762, 9, 762, 5, 68, 68, 729, 1010, 13, 68, 1657, 522, 9, 261, 2762, 11, 68, 68, 485, 1010, 13, 68, 481, 232, 11601, 766, 2762, 9, 81, 4752, 261, 11, 68, 275, 3621, 11444, 182, 317, 9205, 344, 13, 313, 347, 68, 3359, 1449, 344, 201, 81, 12248, 9, 1470, 152, 388, 68, 7085, 3957, 9, 145, 772, 2919, 347, 3153, 4149, 344, 8890, 171, 14, 68, 2417, 347, 519, 145, 232, 414, 918, 13, 81, 9256, 137, 68, 3119
# ...
